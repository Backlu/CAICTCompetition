# %% [markdown]
# ## Case Management

# %%
from IPython.display import HTML
HTML('''<script>
presentation = 0;
code_show=true; 
function code_toggle() {
 if (!presentation){
     return;
 }
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>
''')
# Out:
# <script>
# presentation = 0;
# code_show=true;
# function code_toggle() {
#  if (!presentation){
#      return;
#  }
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
import pandas as pd
import numpy as np
import os
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.colheader_justify','left')

# %%
def generateHtml(table, filename, table_title='--', title='CM-Case Feature Summary'):
    html_str='''
    <html>
    <style type="text/css" scoped>
        <td background-color: rgb(251,251,251);>
    </style>
    <head><meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
       <TITLE>{title}</TITLE> 
    </head>
    <body>
    <CAPTION ALIGN="left">{table_title}</CAPTION>
    {tb}
    </body>
    </html>
    '''.format(title=title, table_title=table_title, tb=table)
    Html_file= open(filename,'w')
    Html_file.write(html_str)
    Html_file.close()
    return html_str

# %%
def insertObservation(df):
    cols=df.columns
    df['observation']=''
    new_cols = cols.insert(1,'observation')
    df =df[new_cols]
    return df

# %%
def addObservations(case, msg, df):
    if isinstance(case, (list, tuple)):
        if isinstance(msg, (list, tuple)):
            pass
        else:
            msg=[msg]*len(case)
        for idx, c in enumerate(case):
            tmp = df.get_value(c,'observation')
            if tmp !='':
                newmsg = '{x},{new}'.format(x=tmp, new=msg[idx])
            else:
                newmsg=msg[idx]
            df.set_value(c,'observation', newmsg)
    else:
        tmp = df.get_value(case,'observation')
        if tmp !='':
            newmsg = '{x},{new}'.format(x=tmp, new=msg)
        else:
            newmsg=msg
        df.set_value(case,'observation', newmsg)

# %% [markdown]
# ***

# %% [markdown]
# ** Index.html **

# %%
def updateIndex():
    filename='case_management/index.html'

    html_files=[]
    for f in os.listdir('case_management'):
        if f.endswith('html'):
            html_files.append(f)

    table_df = pd.DataFrame({'id':range(len(html_files))})

    table_df['files'] = html_files
    table_df['files'] = table_df['files'].apply(lambda x: '<a target="_blank" href="/{file}">{file}</a>'.format(file=x) )
    htmlstr =generateHtml(title='CM-Index', table_title='index', table = table_df.to_html(escape=False,index=False), filename=filename)
    #display(HTML(htmlstr))

    #<a href="/ParameterFeatureSummary.html">test link</a>
updateIndex()

# %% [markdown]
# ** allX **

# %%
cols = ['wind_speed', 'generator_speed', 'power', 'wind_direction',
       'wind_direction_mean', 'yaw_position', 'yaw_speed', 'pitch1_angle',
       'pitch2_angle', 'pitch3_angle', 'pitch1_speed', 'pitch2_speed',
       'pitch3_speed', 'pitch1_moto_tmp', 'pitch2_moto_tmp', 'pitch3_moto_tmp',
       'acc_x', 'acc_y', 'environment_tmp', 'int_tmp', 'pitch1_ng5_tmp',
       'pitch2_ng5_tmp', 'pitch3_ng5_tmp', 'pitch1_ng5_DC', 'pitch2_ng5_DC',
       'pitch3_ng5_DC']

filename='case_management/allX.html'

path_scatter_wind_speed='img/wind_speed/allX/scatter/'#'img/feature_importance/scatter_wind_speed/'
path_scatter_power='img/power/allX/scatter/'#'img/feature_importance/scatter_power/'
#path_heatmap1='img/all/heatmap/'#'img/feature_importance/heatmap1/'
path_rss_wind_speed='img/power/primary_windspeed/RSS/'#'img/feature_importance/rss_wind_speed/'
path_rss_allx='img/power/primary_allx/RSS/'#'img/feature_importance/rss_wind_speed/'
path_distribution='img/all/distribution/'#'img/feature_importance/distribution/'

table_df = pd.DataFrame({'X Factor':cols})
table_df['scatter_power'] = table_df['X Factor'].apply(lambda x: '<img src="{path}{file}.jpg" width=300px/>'.format(path=path_scatter_power, file=x) )
table_df['scatter_wind_speed'] = table_df['X Factor'].apply(lambda x: '<img src="{path}{file}.jpg" width=300px/>'.format(path=path_scatter_wind_speed, file=x) )
table_df['rss_wind_speed'] = table_df['X Factor'].apply(lambda x: '<img src="{path}{file}.jpg" width=300px/>'.format(path=path_rss_wind_speed, file=x) )
table_df['rss_allx'] = table_df['X Factor'].apply(lambda x: '<img src="{path}{file}.jpg" width=300px/>'.format(path=path_rss_allx, file=x) )
table_df['distribution'] = table_df['X Factor'].apply(lambda x: '<img src="{path}{file}.jpg" width=300px/>'.format(path=path_distribution, file=x) )
table_df = insertObservation(table_df)


htmlstr =generateHtml(table = table_df.to_html(escape=False,index=False), filename=filename)
#display(HTML(htmlstr))
updateIndex()

# %%
cols = ['wind_speed', 'generator_speed', 'power', 'wind_direction',
       'wind_direction_mean', 'yaw_position', 'yaw_speed', 'pitch1_angle',
       'pitch2_angle', 'pitch3_angle', 'pitch1_speed', 'pitch2_speed',
       'pitch3_speed', 'pitch1_moto_tmp', 'pitch2_moto_tmp', 'pitch3_moto_tmp',
       'acc_x', 'acc_y', 'environment_tmp', 'int_tmp', 'pitch1_ng5_tmp',
       'pitch2_ng5_tmp', 'pitch3_ng5_tmp', 'pitch1_ng5_DC', 'pitch2_ng5_DC',
       'pitch3_ng5_DC']

filename='case_management/allX_test.html'
table_df = pd.DataFrame({'X Factor':cols})

for y in cols:
    col_name = '{y}'.format(y=y)
    path_scatter='img/{y}/allX/scatter/'.format(y=y)
    table_df[col_name] = table_df['X Factor'].apply(lambda x: '<img src="{path}{file}.jpg" width=300px/>'.format(path=path_scatter, file=x) )


#table_df = insertObservation(table_df)


htmlstr =generateHtml(table = table_df.to_html(escape=False,index=False), filename=filename)
#display(HTML(htmlstr))
updateIndex()

# %% [markdown]
# ** allX (MA)**

# %%
cols = ['wind_speed', 'generator_speed', 'power', 'wind_direction',
       'wind_direction_mean', 'yaw_position', 'yaw_speed', 'pitch1_angle',
       'pitch2_angle', 'pitch3_angle', 'pitch1_speed', 'pitch2_speed',
       'pitch3_speed', 'pitch1_moto_tmp', 'pitch2_moto_tmp', 'pitch3_moto_tmp',
       'acc_x', 'acc_y', 'environment_tmp', 'int_tmp', 'pitch1_ng5_tmp',
       'pitch2_ng5_tmp', 'pitch3_ng5_tmp', 'pitch1_ng5_DC', 'pitch2_ng5_DC',
       'pitch3_ng5_DC']

filename='case_management/allX_ma.html'

#path_scatter_wind_speed='img/wind_speed/allX/scatter/'#'img/feature_importance/scatter_wind_speed/'
path_scatter_power='img/power_ma/allX/scatter/'#'img/feature_importance/scatter_power/'
#path_heatmap1='img/all/heatmap/'#'img/feature_importance/heatmap1/'
path_rss_wind_speed='img/power_ma/primary_windspeed/RSS/'#'img/feature_importance/rss_wind_speed/'
path_distribution='img/all_ma/distribution/'#'img/feature_importance/distribution/'

table_df = pd.DataFrame({'X Factor':cols})
table_df['scatter_power'] = table_df['X Factor'].apply(lambda x: '<img src="{path}{file}.jpg" width=300px/>'.format(path=path_scatter_power, file=x) )
#table_df['scatter_wind_speed'] = table_df['X Factor'].apply(lambda x: '<img src="{path}{file}.jpg" width=300px/>'.format(path=path_scatter_wind_speed, file=x) )
table_df['rss_wind_speed'] = table_df['X Factor'].apply(lambda x: '<img src="{path}{file}.jpg" width=300px/>'.format(path=path_rss_wind_speed, file=x) )
table_df['distribution'] = table_df['X Factor'].apply(lambda x: '<img src="{path}{file}.jpg" width=300px/>'.format(path=path_distribution, file=x) )
table_df = insertObservation(table_df)


htmlstr =generateHtml(table = table_df.to_html(escape=False,index=False), filename=filename)
#display(HTML(htmlstr))
updateIndex()

# %% [markdown]
# ** allX in Case **

# %%
filename='case_management/allXinCase.html'

path_scatter2='img/power/allXIncase/scatter/'#'img/primary_windspeed/scatter2/'

cols = ['wind_speed', 'generator_speed', 'power', 'wind_direction',
        'wind_direction_mean', 'yaw_position', 'yaw_speed', 'pitch1_angle',
        'pitch2_angle', 'pitch3_angle', 'pitch1_speed', 'pitch2_speed',
        'pitch3_speed', 'pitch1_moto_tmp', 'pitch2_moto_tmp', 'pitch3_moto_tmp',
        'acc_x', 'acc_y', 'environment_tmp', 'int_tmp', 'pitch1_ng5_tmp',
        'pitch2_ng5_tmp', 'pitch3_ng5_tmp', 'pitch1_ng5_DC', 'pitch2_ng5_DC',
        'pitch3_ng5_DC']


table_df = pd.DataFrame({'Event id':range(25)})
for x in cols:
    table_df[x] = table_df['Event id'].apply(lambda e: '<img src="{path}{x}{e}.jpg" width=150px/>'.format(path=path_scatter2, e=e, x=x) )

table_df = insertObservation(table_df)

dum = table_df.style.set_properties(**{'text-align': 'left'})
htmlstr =generateHtml(table = table_df.to_html(escape=False,index=False), filename=filename)
#display(HTML(htmlstr))
updateIndex()

# %% [markdown]
# ** allX in Case (MA)**

# %%
filename='case_management/allXinCase_ma.html'

path_scatter2='img/power_ma/allXIncase/scatter/'#'img/primary_windspeed/scatter2/'

cols = ['wind_speed', 'generator_speed', 'power', 'wind_direction',
        'wind_direction_mean', 'yaw_position', 'yaw_speed', 'pitch1_angle',
        'pitch2_angle', 'pitch3_angle', 'pitch1_speed', 'pitch2_speed',
        'pitch3_speed', 'pitch1_moto_tmp', 'pitch2_moto_tmp', 'pitch3_moto_tmp',
        'acc_x', 'acc_y', 'environment_tmp', 'int_tmp', 'pitch1_ng5_tmp',
        'pitch2_ng5_tmp', 'pitch3_ng5_tmp', 'pitch1_ng5_DC', 'pitch2_ng5_DC',
        'pitch3_ng5_DC']


table_df = pd.DataFrame({'Event id':range(25)})
for x in cols:
    table_df[x] = table_df['Event id'].apply(lambda e: '<img src="{path}{x}{e}.jpg" width=150px/>'.format(path=path_scatter2, e=e, x=x) )

table_df = insertObservation(table_df)

dum = table_df.style.set_properties(**{'text-align': 'left'})
htmlstr =generateHtml(table = table_df.to_html(escape=False,index=False), filename=filename)
#display(HTML(htmlstr))
updateIndex()

# %% [markdown]
# ** Primary(wind_speed) in Case**

# %%
filename='case_management/primary(wind_speed)InCase.html'

path_scatter1='img/power/primary_windspeed/scatter/'#'img/primary_windspeed/scatter1/'
path_trend1='img/power/primary_windspeed/trend_d/'#'img/primary_windspeed/trend1/'
path_trend2='img/power/primary_windspeed/trend_t/'#'img/primary_windspeed/trend2/'

table_df = pd.DataFrame({'Event id':range(25)})
table_df['power-wind_speed_scatter'] = table_df['Event id'].apply(lambda x: '<img src="{path}{file}.jpg" width=250px/>'.format(path=path_scatter1, file=x) )
table_df['trend1(datapoint)'] = table_df['Event id'].apply(lambda x: '<img src="{path}{file}.jpg" width=1000px/>'.format(path=path_trend1, file=x) )
table_df['trend(timestamp)'] = table_df['Event id'].apply(lambda x: '<img src="{path}{file}.jpg" width=1000px/>'.format(path=path_trend2, file=x) )
table_df = insertObservation(table_df)

addObservations(case=[1,6,7,9,11,13,14,15,16,17,20],msg='左下角異常', df=table_df)
#addObservations(case=[0,3,4,5,8,10,12,18,19,21,22,23,24],msg='正常', df=table_df)


table_df.style.set_properties(**{'text-align': 'left'})
htmlstr =generateHtml(table_title='Primary_Parameter(wind_speed)', table = table_df.to_html(escape=False,index=False), filename=filename)
#display(HTML(htmlstr))
updateIndex()

# %% [markdown]
# ** Primary(wind_speed) in Case (MA) **

# %%
filename='case_management/primary(wind_speed)InCase_ma.html'

path_scatter1='img/power_ma/primary_windspeed/scatter/'#'img/primary_windspeed/scatter1/'
path_trend1='img/power_ma/primary_windspeed/trend_d/'#'img/primary_windspeed/trend1/'
path_trend2='img/power_ma/primary_windspeed/trend_t/'#'img/primary_windspeed/trend2/'

table_df = pd.DataFrame({'Event id':range(25)})
table_df['power-wind_speed_scatter'] = table_df['Event id'].apply(lambda x: '<img src="{path}{file}.jpg" width=250px/>'.format(path=path_scatter1, file=x) )
table_df['trend1(datapoint)'] = table_df['Event id'].apply(lambda x: '<img src="{path}{file}.jpg" width=1000px/>'.format(path=path_trend1, file=x) )
table_df['trend(timestamp)'] = table_df['Event id'].apply(lambda x: '<img src="{path}{file}.jpg" width=1000px/>'.format(path=path_trend2, file=x) )
table_df = insertObservation(table_df)

#addObservations(case=[1,6,7,9,11,13,14,15,16,17,20],msg='左下角異常', df=table_df)
#addObservations(case=[0,3,4,5,8,10,12,18,19,21,22,23,24],msg='正常', df=table_df)


table_df.style.set_properties(**{'text-align': 'left'})
htmlstr =generateHtml(table_title='Primary_Parameter_MA(wind_speed)', table = table_df.to_html(escape=False,index=False), filename=filename)
#display(HTML(htmlstr))
updateIndex()

# %% [markdown]
# ** Primary(allX) in Case**
#   - without generator_speed

# %%
filename='case_management/primary(allX)InCase.html'

path_scatter1='img/power/primary_allx/scatter/'#'img/primary_windspeed/scatter1/'
path_scatter2='img/power/primary_allx/scatter2/'
path_scatter3='img/power/primary_allx/scatter3/'
path_trend1='img/power/primary_allx/trend_d/'#'img/primary_windspeed/trend1/'
path_trend1_dif='img/power/primary_allx/trend_d_dif/'
path_trend2='img/power/primary_allx/trend_t/'#'img/primary_windspeed/trend2/'

table_df = pd.DataFrame({'Event id':range(25)})
table_df['power-wind_speed_scatter'] = table_df['Event id'].apply(lambda x: '<img src="{path}{file}.jpg" width=250px/>'.format(path=path_scatter1, file=x) )
table_df['power-predPower_scatter'] = table_df['Event id'].apply(lambda x: '<img src="{path}{file}.jpg" width=250px/>'.format(path=path_scatter2, file=x) )
table_df['power-predPower_scatter2'] = table_df['Event id'].apply(lambda x: '<img src="{path}{file}.jpg" width=250px/>'.format(path=path_scatter3, file=x) )
table_df['trend1(datapoint)'] = table_df['Event id'].apply(lambda x: '<img src="{path}{file}.jpg" width=1000px/>'.format(path=path_trend1, file=x) )
table_df['trend1(diff)'] = table_df['Event id'].apply(lambda x: '<img src="{path}{file}.jpg" width=1000px/>'.format(path=path_trend1_dif, file=x) )
table_df['trend(timestamp)'] = table_df['Event id'].apply(lambda x: '<img src="{path}{file}.jpg" width=1000px/>'.format(path=path_trend2, file=x) )
table_df = insertObservation(table_df)

#addObservations(case=[1,6,7,9,11,13,14,15,16,17,20],msg='左下角異常', df=table_df)
#addObservations(case=[0,3,4,5,8,10,12,18,19,21,22,23,24],msg='正常', df=table_df)


table_df.style.set_properties(**{'text-align': 'left'})
htmlstr =generateHtml(table_title='Primary_Parameter(allX without generator_speed2)', table = table_df.to_html(escape=False,index=False), filename=filename)
#display(HTML(htmlstr))
updateIndex()
# Out:
#     <html>
#     <style type="text/css" scoped>
#         <td background-color: rgb(251,251,251);>
#     </style>
#     <head><meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
#        <TITLE>CM-Case Feature Summary</TITLE>
#     </head>
#     <body>
#     <CAPTION ALIGN="left">Primary_Parameter(allX without generator_speed2)</CAPTION>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Event id</th>
#       <th>observation</th>
#       <th>power-wind_speed_scatter</th>
#       <th>power-predPower_scatter</th>
#       <th>power-predPower_scatter2</th>
#       <th>trend1(datapoint)</th>
#       <th>trend1(diff)</th>
#       <th>trend(timestamp)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td></td>
#       <td><img src="img/power/primary_allx/scatter/0.jpg" width=250px/></td>
#       <td><img src="img/power/primary_allx/scatter2/0.jpg" width=250px/></td>
#       <td><img src="img/power/primary_allx/scatter3/0.jpg" width=250px/></td>
#       <td><img src="img/power/primary_allx/trend_d/0.jpg" width=1000px/></td>
#       <td><img src="img/power/primary_allx/trend_d_dif/0.jpg" width=1000px/></td>
#       <td><img src="img/power/primary_allx/trend_t/0.jpg" width=1000px/></td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td></td>
#       <td><img src="img/power/primary_allx/scatter/1.jpg" width=250px/></td>
#       <td><img src="img/power/primary_allx/scatter2/1.jpg" width=250px/></td>
#       <td><img src="img/power/primary_allx/scatter3/1.jpg" width=250px/></td>
#       <td><img src="img/power/primary_allx/trend_d/1.jpg" width=1000px/></td>
#       <td><img src="img/power/primary_allx/trend_d_dif/1.jpg" width=1000px/></td>
#       <td><img src="img/power/primary_allx/trend_t/1.jpg" width=1000px/></td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td></td>
#       <td><img src="img/power/primary_allx/scatter/2.jpg" width=250px/></td>
#       <td><img src="img/power/primary_allx/scatter2/2.jpg" width=250px/></td>
#       <td><img src="img/power/primary_allx/scatter3/2.jpg" width=250px/></td>
#       <td><img src="img/power/primary_allx/trend_d/2.jpg" width=1000px/></td>
#       <td><img src="img/power/primary_allx/trend_d_dif/2.jpg" width=1000px/></td>
#       <td><img src="img/power/primary_allx/trend_t/2.jpg" width=1000px/></td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td></td>
#       <td><img src="img/power/primary_allx/scatter/3.jpg" width=250px/></td>
#       <td><img src="img/power/primary_allx/scatter2/3.jpg" width=250px/></td>
#       <td><img src="img/power/primary_allx/scatter3/3.jpg" width=250px/></td>
#       <td><img src="img/power/primary_allx/trend_d/3.jpg" width=1000px/></td>
#       <td><img src="img/power/primary_allx/trend_d_dif/3.jpg" width=1000px/></td>
#       <td><img src="img/power/primary_allx/trend_t/3.jpg" width=1000px/></td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td></td>
#       <td><img src="img/power/primary_allx/scatter/4.jpg" width=250px/></td>
#       <td><img src="img/power/primary_allx/scatter2/4.jpg" width=250px/></td>
#       <td><img src="img/power/primary_allx/scatter3/4.jpg" width=250px/></td>
#       <td><img src="img/power/primary_allx/trend_d/4.jpg" width=1000px/></td>
#       <td><img src="img/power/primary_allx/trend_d_dif/4.jpg" width=1000px/></td>
#       <td><img src="img/power/primary_allx/trend_t/4.jpg" width=1000px/></td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td></td>
#       <td><img src="img/power/primary_allx/scatter/5.jpg" width=250px/></td>
#       <td><img src="img/power/primary_allx/scatter2/5.jpg" width=250px/></td>
#       <td><img src="img/power/primary_allx/scatter3/5.jpg" width=250px/></td>
#       <td><img src="img/power/primary_allx/trend_d/5.jpg" width=1000px/></td>
#       <td><img src="img/power/primary_allx/trend_d_dif/5.jpg" width=1000px/></td>
#       <td><img src="img/power/primary_allx/trend_t/5.jpg" width=1000px/></td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td></td>
#       <td><img src="img/power/primary_allx/scatter/6.jpg" width=250px/></td>
#       <td><img src="img/power/primary_allx/scatter2/6.jpg" width=250px/></td>
#       <td><img src="img/power/primary_allx/scatter3/6.jpg" width=250px/></td>
#       <td><img src="img/power/primary_allx/trend_d/6.jpg" width=1000px/></td>
#       <td><img src="img/power/primary_allx/trend_d_dif/6.jpg" width=1000px/></td>
#       <td><img src="img/power/primary_allx/trend_t/6.jpg" width=1000px/></td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td></td>
#       <td><img src="img/power/primary_allx/scatter/7.jpg" width=250px/></td>
#       <td><img src="img/power/primary_allx/scatter2/7.jpg" width=250px/></td>
#       <td><img src="img/power/primary_allx/scatter3/7.jpg" width=250px/></td>
#       <td><img src="img/power/primary_allx/trend_d/7.jpg" width=1000px/></td>
#       <td><img src="img/power/primary_allx/trend_d_dif/7.jpg" width=1000px/></td>
#       <td><img src="img/power/primary_allx/trend_t/7.jpg" width=1000px/></td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td></td>
#       <td><img src="img/power/primary_allx/scatter/8.jpg" width=250px/></td>
#       <td><img src="img/power/primary_allx/scatter2/8.jpg" width=250px/></td>
#       <td><img src="img/power/primary_allx/scatter3/8.jpg" width=250px/></td>
#       <td><img src="img/power/primary_allx/trend_d/8.jpg" width=1000px/></td>
#       <td><img src="img/power/primary_allx/trend_d_dif/8.jpg" width=1000px/></td>
#       <td><img src="img/power/primary_allx/trend_t/8.jpg" width=1000px/></td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td></td>
#       <td><img src="img/power/primary_allx/scatter/9.jpg" width=250px/></td>
#       <td><img src="img/power/primary_allx/scatter2/9.jpg" width=250px/></td>
#       <td><img src="img/power/primary_allx/scatter3/9.jpg" width=250px/></td>
#       <td><img src="img/power/primary_allx/trend_d/9.jpg" width=1000px/></td>
#       <td><img src="img/power/primary_allx/trend_d_dif/9.jpg" width=1000px/></td>
#       <td><img src="img/power/primary_allx/trend_t/9.jpg" width=1000px/></td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td></td>
#       <td><img src="img/power/primary_allx/scatter/10.jpg" width=250px/></td>
#       <td><img src="img/power/primary_allx/scatter2/10.jpg" width=250px/></td>
#       <td><img src="img/power/primary_allx/scatter3/10.jpg" width=250px/></td>
#       <td><img src="img/power/primary_allx/trend_d/10.jpg" width=1000px/></td>
#       <td><img src="img/power/primary_allx/trend_d_dif/10.jpg" width=1000px/></td>
#       <td><img src="img/power/primary_allx/trend_t/10.jpg" width=1000px/></td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td></td>
#       <td><img src="img/power/primary_allx/scatter/11.jpg" width=250px/></td>
#       <td><img src="img/power/primary_allx/scatter2/11.jpg" width=250px/></td>
#       <td><img src="img/power/primary_allx/scatter3/11.jpg" width=250px/></td>
#       <td><img src="img/power/primary_allx/trend_d/11.jpg" width=1000px/></td>
#       <td><img src="img/power/primary_allx/trend_d_dif/11.jpg" width=1000px/></td>
#       <td><img src="img/power/primary_allx/trend_t/11.jpg" width=1000px/></td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td></td>
#       <td><img src="img/power/primary_allx/scatter/12.jpg" width=250px/></td>
#       <td><img src="img/power/primary_allx/scatter2/12.jpg" width=250px/></td>
#       <td><img src="img/power/primary_allx/scatter3/12.jpg" width=250px/></td>
#       <td><img src="img/power/primary_allx/trend_d/12.jpg" width=1000px/></td>
#       <td><img src="img/power/primary_allx/trend_d_dif/12.jpg" width=1000px/></td>
#       <td><img src="img/power/primary_allx/trend_t/12.jpg" width=1000px/></td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td></td>
#       <td><img src="img/power/primary_allx/scatter/13.jpg" width=250px/></td>
#       <td><img src="img/power/primary_allx/scatter2/13.jpg" width=250px/></td>
#       <td><img src="img/power/primary_allx/scatter3/13.jpg" width=250px/></td>
#       <td><img src="img/power/primary_allx/trend_d/13.jpg" width=1000px/></td>
#       <td><img src="img/power/primary_allx/trend_d_dif/13.jpg" width=1000px/></td>
#       <td><img sr

# %% [markdown]
# ** Primary(allX) in Case**
#   - with generator_speed

# %%
filename='case_management/primary(allX)InCase.html'

path_scatter1='img/power/primary_allx2/scatter/'#'img/primary_windspeed/scatter1/'
path_scatter2='img/power/primary_allx2/scatter2/'
path_trend1='img/power/primary_allx2/trend_d/'#'img/primary_windspeed/trend1/'
path_trend2='img/power/primary_allx2/trend_t/'#'img/primary_windspeed/trend2/'

table_df = pd.DataFrame({'Event id':range(25)})
table_df['power-wind_speed_scatter'] = table_df['Event id'].apply(lambda x: '<img src="{path}{file}.jpg" width=250px/>'.format(path=path_scatter1, file=x) )
table_df['power-predPower_scatter'] = table_df['Event id'].apply(lambda x: '<img src="{path}{file}.jpg" width=250px/>'.format(path=path_scatter2, file=x) )
table_df['trend1(datapoint)'] = table_df['Event id'].apply(lambda x: '<img src="{path}{file}.jpg" width=1000px/>'.format(path=path_trend1, file=x) )
table_df['trend(timestamp)'] = table_df['Event id'].apply(lambda x: '<img src="{path}{file}.jpg" width=1000px/>'.format(path=path_trend2, file=x) )
table_df = insertObservation(table_df)

#addObservations(case=[1,6,7,9,11,13,14,15,16,17,20],msg='左下角異常', df=table_df)
#addObservations(case=[0,3,4,5,8,10,12,18,19,21,22,23,24],msg='正常', df=table_df)


table_df.style.set_properties(**{'text-align': 'left'})
htmlstr =generateHtml(table_title='Primary_Parameter(allX with generator_speed)', table = table_df.to_html(escape=False,index=False), filename=filename)
#display(HTML(htmlstr))
updateIndex()

# %% [markdown]
# ***
